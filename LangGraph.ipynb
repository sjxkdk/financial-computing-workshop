# %% [markdown]
# # LangGraph:  Agent Orchestration
#
# #### By Pedro Izquierdo Lehmann
#
# Welcome back! This last notebook is the second part of the LangChain notebook. We will explore the **LangGraph** library, which is built on top of LangChain, and is useful for the controlled design of complex workflows with or without loops, encompassing **agents orchestration**.
#
# Also, we will not use the openAI API, but we will query locally stored LLMs using Ollama.

# %% [markdown]
# ---
# ## (0. Environment Setup)
#
# Before starting, set up a Python virtual environment and install required dependencies.
#
# #### 1. Create a Virtual Environment
#
# ```bash
# python3 -m venv lang-graph
# ```
#
# #### 2. Activate the Virtual Environment
#
# **On macOS/Linux:**
# ```bash
# source lang-graph/bin/activate
# ```
#
# **On Windows:**
# ```bash
# lang-graph\Scripts\activate
# ```
#
# #### 3. Install Required Dependencies
#
# ```bash
# pip install langchain langgraph langchain-ollama jupyter ipykernel
# ```
#
# Install Ollama (required for local LLMs):
#
# ```bash
# # macOS (Homebrew)
# brew install ollama
# brew services start ollama
#
# # Linux
# curl -fsSL https://ollama.com/install.sh | sh
#
# # Windows: download the installer
# # https://ollama.com/download
# ```
#
# #### 4. Register the Kernel
#
# ```bash
# python -m ipykernel install --user --name=lang-graph --display-name "Python (lang-graph)"
# ```
#
# #### 5. Start Jupyter
#
# ```bash
# jupyter notebook
# ```
#
# #### 6. Deactivate
#
# ```bash
# deactivate
# ```

# %%
# python3 -m venv lang-graph
# source lang-graph/bin/activate
# lang-graph\Scripts\activate
# pip install langchain langgraph langchain-ollama jupyter ipykernel

# %%
# Install Ollama (required for local LLMs)
# macOS (Homebrew): brew install ollama
#                   brew services start ollama
# Linux: curl -fsSL https://ollama.com/install.sh | sh
# Windows: https://ollama.com/download

# %%
# python -m ipykernel install --user --name=lang-graph --display-name "Python (lang-graph)"
# jupyter notebook
# deactivate

# %% [markdown]
# #### Ollama Setup
#
# All model calls in this notebook must run **locally** via Ollama.
#
# 1. Start the Ollama server (separate terminal if needed)
# 2. Pull a local model (you can change the model name later)
# 3. Verify that Ollama can list your models
#
# Run the code cell below in order.

# %%
# Check that Ollama is installed and running
# !ollama --version
# !ollama list

# Pull a local model (edit if you want a different one)
OLLAMA_MODEL = "llama3.1"
# !ollama pull {OLLAMA_MODEL}

# If Ollama is not running, start it in a separate terminal:
# !ollama serve
# Out:
# ollama version is 0.14.2
# NAME    ID    SIZE    MODIFIED
# pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest 鉅� pulling manifest
# pulling 667b0c1932bc:   0% 鈻�                  鈻� 1.4 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   0% 鈻�                  鈻� 6.1 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   0% 鈻�                  鈻�  19 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  27 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  31 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  37 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  43 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  47 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  53 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  59 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  63 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   1% 鈻�                  鈻�  69 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻�  76 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻�  79 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻�  85 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻�  91 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻�  95 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻� 101 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻� 107 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻� 111 MB/4.9 GB   63 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:   2% 鈻�                  鈻� 117 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 124 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 127 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 133 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 140 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 143 MB/4.9 GB   58 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 149 MB/4.9 GB   58 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 156 MB/4.9 GB   58 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 159 MB/4.9 GB   58 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   3% 鈻�                  鈻� 165 MB/4.9 GB   58 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 172 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 175 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 181 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 188 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 191 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 197 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 204 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 207 MB/4.9 GB   57 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 214 MB/4.9 GB   57 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   4% 鈻�                  鈻� 220 MB/4.9 GB   57 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 223 MB/4.9 GB   57 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 229 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 236 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 239 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 246 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 252 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 255 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 262 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   5% 鈻�                  鈻� 268 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻�                  鈻� 271 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 278 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 284 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 287 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 294 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 300 MB/4.9 GB   56 MB/s   1m22spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 304 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 310 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   6% 鈻曗枅                 鈻� 316 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 320 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 326 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 332 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 336 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 342 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 348 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 352 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 358 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 365 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   7% 鈻曗枅                 鈻� 368 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 374 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 380 MB/4.9 GB   56 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 384 MB/4.9 GB   56 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 390 MB/4.9 GB   55 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 397 MB/4.9 GB   55 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 400 MB/4.9 GB   55 MB/s   1m21spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 406 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 413 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   8% 鈻曗枅                 鈻� 416 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 422 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 429 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 432 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 438 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 445 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 448 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 454 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 461 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:   9% 鈻曗枅                 鈻� 464 MB/4.9 GB   55 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 471 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 477 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 480 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 487 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 493 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 496 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 503 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 509 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  10% 鈻曗枅                 鈻� 512 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 519 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 525 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 528 MB/4.9 GB   55 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 535 MB/4.9 GB   55 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 541 MB/4.9 GB   55 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅                 鈻� 544 MB/4.9 GB   55 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅鈻�                鈻� 551 MB/4.9 GB   55 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅鈻�                鈻� 552 MB/4.9 GB   54 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅鈻�                鈻� 553 MB/4.9 GB   54 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅鈻�                鈻� 558 MB/4.9 GB   54 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  11% 鈻曗枅鈻�                鈻� 562 MB/4.9 GB   54 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 569 MB/4.9 GB   54 MB/s   1m20spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 576 MB/4.9 GB   54 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 585 MB/4.9 GB   54 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 590 MB/4.9 GB   54 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 599 MB/4.9 GB   54 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 605 MB/4.9 GB   54 MB/s   1m19spulling manifest
# pulling 667b0c1932bc:  12% 鈻曗枅鈻�                鈻� 609 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 615 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 621 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 625 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 631 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 637 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 641 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 647 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 654 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 657 MB/4.9 GB   54 MB/s   1m18spulling manifest
# pulling 667b0c1932bc:  13% 鈻曗枅鈻�                鈻� 663 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 669 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 673 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 679 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 686 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 689 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 695 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 702 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 705 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  14% 鈻曗枅鈻�                鈻� 710 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 716 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 719 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 725 MB/4.9 GB   54 MB/s   1m17spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 732 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 735 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 741 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 748 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 751 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  15% 鈻曗枅鈻�                鈻� 757 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 764 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 767 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 773 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 780 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 783 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 789 MB/4.9 GB   54 MB/s   1m16spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 796 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 799 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  16% 鈻曗枅鈻�                鈻� 806 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻�                鈻� 812 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻�                鈻� 815 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 822 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 828 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 831 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 838 MB/4.9 GB   54 MB/s   1m15spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 844 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 847 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 854 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  17% 鈻曗枅鈻堚枅               鈻� 860 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 863 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 870 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 876 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 879 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 886 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 892 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 895 MB/4.9 GB   54 MB/s   1m14spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 902 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  18% 鈻曗枅鈻堚枅               鈻� 908 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 911 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 918 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 924 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 927 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 934 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 940 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 943 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 950 MB/4.9 GB   54 MB/s   1m13spulling manifest
# pulling 667b0c1932bc:  19% 鈻曗枅鈻堚枅               鈻� 956 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 959 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 966 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 972 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 975 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 982 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 988 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 992 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 998 MB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  20% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m12spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m11spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.0 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  21% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅               鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  22% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s   1m10spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.1 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  23% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m9spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  24% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m8spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.2 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  25% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m7spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  26% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m6spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.3 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  27% 鈻曗枅鈻堚枅鈻�              鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻�              鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻�              鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  28% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m5spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   54 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.4 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  29% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m4spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  30% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m3spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  31% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.5 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m2spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  32% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m1spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅             鈻� 1.6 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.6 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  33% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.6 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.6 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s    1m0spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  34% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   53 MB/s     59spulling manifest
# pulling 667b0c1932bc:  35% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.7 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     58spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  36% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     57spulling manifest
# pulling 667b0c1932bc:  37% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.8 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     56spulling manifest
# pulling 667b0c1932bc:  38% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻�            鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     55spulling manifest
# pulling 667b0c1932bc:  39% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 1.9 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     54spulling manifest
# pulling 667b0c1932bc:  40% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     53spulling manifest
# pulling 667b0c1932bc:  41% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.0 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  42% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     52spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  43% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     51spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.1 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  44% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅           鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     50spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  45% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.2 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     49spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  46% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     48spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     47spulling manifest
# pulling 667b0c1932bc:  47% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   54 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.3 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  48% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     47spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  49% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     46spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.4 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻�          鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  50% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     45spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     44spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     44spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     44spulling manifest
# pulling 667b0c1932bc:  51% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅         鈻� 2.5 GB/4.9 GB   53 MB/s     44spulling manifest
# ...
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest 鉅� pulling manifest
# pulling 667b0c1932bc: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 4.9 GB
# pulling 948af2743fc7: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏 1.5 KB
# pulling 0ba8f0e314b4: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  12 KB
# pulling 56bb8bd477a5: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏   96 B
# pulling 455f34728c9b: 100% 鈻曗枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
from typing import TypedDict, Annotated, Literal
from dataclasses import dataclass, field
import operator
import math

from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage, BaseMessage
from langchain_core.tools import tool
from langchain.agents import create_agent

from langgraph.graph import StateGraph, START, END, add_messages
from langgraph.checkpoint.memory import InMemorySaver

from ollama import chat
from ollama import ChatResponse

# %%
response: ChatResponse = chat(model='llama3.1', messages=[
  {
    'role': 'user',
    'content': 'Please discuss the conversion of Phillips 66 from oil to renewable diesel.',
  },
])
print(response.message.content)
# Out:
# You're likely referring to the significant transformation that Phillips 66, a leading U.S.-based energy company, has undergone in recent years.
#
# Phillips 66 is shifting its focus towards becoming a more diversified and sustainable energy company, with an increased emphasis on producing renewable fuels. While they are still involved in oil refining and marketing, their strategy includes investing heavily in the production of renewable diesel (RD) and other low-carbon fuels.
#
# Here's an overview of their conversion efforts:
#
# **Background:**
# In 2015, Phillips 66 acquired a 49% stake in Dakota Access Pipeline (DAPL), which transports crude oil from North Dakota to Illinois. However, this deal was met with significant opposition due to environmental and social concerns associated with the pipeline.
#
# **Renewable Diesel (RD) Production:**
# To mitigate these concerns and transition towards more sustainable operations, Phillips 66 is investing in renewable diesel production at several of its refineries. Renewable diesel is a low-carbon fuel made from non-food biomass or waste materials, such as agricultural residues or municipal solid waste. This process involves converting vegetable oils or animal fats into a drop-in replacement for traditional fossil-based diesel.
#
# Phillips 66 has committed to investing $500 million in the production of renewable diesel at its refineries in California and Louisiana, with plans to reach 1 billion gallons per year by 2025. The company is also exploring opportunities to produce renewable jet fuel and other low-carbon fuels.
#
# **Why Renewable Diesel?**
# Renewable diesel offers several advantages over traditional fossil-based diesel:
#
# 1. **Lower greenhouse gas emissions:** RD can reduce carbon emissions by up to 80% compared to conventional diesel.
# 2. **Improved air quality:** RD produces fewer particulate matter, nitrogen oxides, and volatile organic compounds (VOCs) than traditional diesel.
# 3. **Compatibility with existing infrastructure:** RD is a drop-in replacement for traditional diesel, making it easily integrable into the transportation fuel market.
#
# **Challenges and Opportunities:**
# While Phillips 66's conversion to renewable diesel production presents opportunities for growth in the low-carbon fuels market, there are also challenges:
#
# 1. **Cost:** The cost of producing RD can be higher than traditional fossil-based diesel.
# 2. **Feedstock availability:** Ensuring a consistent supply of biomass or waste materials is crucial for large-scale RD production.
# 3. **Regulatory support:** Governments and regulatory bodies will need to provide supportive policies and incentives for the development of low-carbon fuels.
#
# **Conclusion:**
# Phillips 66's transformation from oil-focused operations to renewable diesel production marks an important shift in the energy industry. By investing in sustainable fuels, Phillips 66 is adapting to changing market demands and reducing its environmental footprint. The success of this strategy will depend on various factors, including the availability of biomass feedstocks, economies of scale, and regulatory support for low-carbon fuels.

# %%
# LLM (local via Ollama)
OLLAMA_MODEL = "llama3.1"
llm = ChatOllama(model=OLLAMA_MODEL, temperature=0)

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Graphs for Agentic AI
#
# LangChain gives you **tools** and **agents**, but the control flow still lives inside the LLM loop; the default ReAct pattern is sufficient. Effectively, the chains of LangChain are directed acyclic graphs (DAGs), where
#
# - **Nodes** are explicit steps (LLM calls or Python logic)
# - **Edges** define how control flows between steps
# - **State** is a typed object that persists across the graph.
#
# > **Note**: The graph state is the central, typed data structure that flows through nodes and is mutated by each node. It’s the single source of truth for the workflow at any step (messages, intermediate results, flags, etc.). Every node reads from it and returns partial updates to it.
#
# > **Keep in mind**: The graph state, `ToolRuntime`, and `InMemorySaver` all relate to “runtime context,” but they operate at different layers.
# >- The LangGraph state is the _actual working state_ your nodes read/write.
# >- `ToolRuntime` is a _tool-level context injection_ (useful for user/session info), not a state container.
# >- `InMemorySaver` is _storage_ so state can be resumed later; it does not define state, it just saves it.
#
# With LangGraph one can construct explicitly a **graph** workflow that may have **cycles**, allowing for more workflow expressivity. Also, it provides conditional routing along the graph; much more control over the workflow is possible.

# %% [markdown]
# The following is an example of an agentic workflow graph. Notice how we **separate reasoning from deterministic checks**, which is hard to guarantee with a pure agent loop.

# %%
# This graph receives financial macros in text and the returns of an asset, then it summarizes the text and computes the volatility of the asset, and then it provides a one-sentence implication for a long-only equity portfolio.
# Graph: summarize macro -> compute volatility -> final brief (linear DAG)
macro_headlines = [
    "CPI comes in below expectations; core inflation cools",
    "Fed signals pause; markets price in two cuts",
    "Oil spikes on supply concerns",
]

returns = [0.002, -0.004, 0.001, 0.003, -0.002, 0.0005, -0.001]

class MacroState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    macro_summary: str
    realized_vol: float
    risk_bucket: str


def summarize_macro(state: MacroState):
    prompt = (
        "Summarize these headlines into a 2-sentence macro brief for an equity analyst:\n"
        + "\n".join(f"- {h}" for h in macro_headlines)
    )
    response = llm.invoke([SystemMessage(content=prompt)])
    return {"messages": [response], "macro_summary": response.content}


def compute_vol(state: MacroState):
    daily_vol = math.sqrt(sum(r * r for r in returns) / len(returns))
    annualized = daily_vol * math.sqrt(252)
    if annualized < 0.15:
        bucket = "LOW"
    elif annualized < 0.25:
        bucket = "MEDIUM"
    else:
        bucket = "HIGH"
    return {"realized_vol": annualized, "risk_bucket": bucket}


def final_brief(state: MacroState):
    content = (
        f"Macro brief: {state['macro_summary']}\n"
        f"Risk overlay: realized vol {state['realized_vol']:.2%} -> {state['risk_bucket']} risk.\n"
        "Provide a one-sentence implication for a long-only equity portfolio."
    )
    response = llm.invoke([HumanMessage(content=content)])
    return {"messages": [response]}


builder = StateGraph(MacroState)
builder.add_node("summarize_macro", summarize_macro)
builder.add_node("compute_vol", compute_vol)
builder.add_node("final_brief", final_brief)

builder.add_edge(START, "summarize_macro")
builder.add_edge("summarize_macro", "compute_vol")
builder.add_edge("compute_vol", "final_brief")
builder.add_edge("final_brief", END)

macro_graph = builder.compile()

result = macro_graph.invoke({"messages": []})
print(result["messages"][-1].content)
# Out:
# The low realized volatility suggests that the market may be due for a correction, implying that it may be prudent to reduce exposure or maintain a defensive stance in a long-only equity portfolio.

# %% [markdown]
# If you want to visualize the graph structure:

# %%
from IPython.display import Image, display

# Mermaid text diagram (paste into a Mermaid renderer if needed)
print(macro_graph.get_graph().draw_mermaid())
display(Image(macro_graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Exercise 1: Add a Position Sizing Node
#
# Example above uses a three-step flow: summarize macro, compute volatility, and final brief. Now add a **position sizing** node that sets a target exposure based on the risk bucket:
#
# - LOW -> 1.0
# - MEDIUM -> 0.6
# - HIGH -> 0.3
#
# Then include the target exposure in the final response.

# %%
# EXERCISE: Add a position sizing node
# 1. Create a node `position_size(state)` that returns target_exposure
# 2. Insert it between compute_vol and final_brief
# 3. Update final_brief to include target_exposure

class MacroState2(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    macro_summary: str
    realized_vol: float
    risk_bucket: str
    target_exposure: float


# TODO: define position_size
def position_size(state: MacroState2):
    # [cite_start]根据风险分桶设置目标仓位 [cite: 744-746]
    risk = state["risk_bucket"]
    if risk == "LOW":
        exposure = 1.0
    elif risk == "MEDIUM":
        exposure = 0.6
    else: # HIGH
        exposure = 0.3
    return {"target_exposure": exposure}


# TODO: update final_brief to use target_exposure
def final_brief(state: MacroState2):
    # [cite_start]构建包含仓位建议的提示词 [cite: 747-749]
    content = (
        f"Macro brief: {state['macro_summary']}\n"
        f"Risk overlay: realized vol {state['realized_vol']:.2%}, bucket {state['risk_bucket']}\n"
        f"Position sizing: target exposure {state['target_exposure']}\n"
        "Provide a one-sentence recommendation."
    )
    response = llm.invoke(content)
    return {"messages": [response]}


# TODO: build and run the graph with the new node
builder = StateGraph(MacroState2)

# [cite_start]添加所有节点 (summarize_macro 和 compute_vol 复用之前定义的函数) [cite: 721-723]
builder.add_node("summarize_macro", summarize_macro)
builder.add_node("compute_vol", compute_vol)
builder.add_node("position_size", position_size) # 新增节点
builder.add_node("final_brief", final_brief)     # 更新后的节点

# [cite_start]定义边的连接顺序 [cite: 751]
builder.add_edge(START, "summarize_macro")
builder.add_edge("summarize_macro", "compute_vol")
builder.add_edge("compute_vol", "position_size") # 插入中间
builder.add_edge("position_size", "final_brief")
builder.add_edge("final_brief", END)

# 编译图
macro_graph_2 = builder.compile()

# 运行图
# 注意：这里需要传入初始状态，假设 macro_headlines 和 returns 是之前定义的全局变量
result = macro_graph_2.invoke({
    "messages": [("user", "Analyze portfolio inputs")]
})

print(result["messages"][-1].content)
# Out:
# Reduce the portfolio's overall risk by decreasing position sizes to maintain a target exposure of 1.0, given the high realized volatility and "LOW" bucket designation.

# %% [markdown]
# ## 2. Streaming
#
# LangGraph supports streaming, allowing you to see agent responses in real-time as they're generated. This is essential for building responsive user interfaces.
#
# Below is a simple example that streams node updates as the graph executes. This is especially useful in finance dashboards where you want to show partial progress as each step completes.

# %%
# We will use the same macro_graph as before

def print_updates(event: dict):
    for node, update in event.items():
        if isinstance(update, dict) and update.get("messages"):
            print(f"[{node}] {update['messages'][-1].content}")
        else:
            print(f"[{node}] {update}")


for event in macro_graph.stream({"messages": []}, stream_mode="updates"):
    print_updates(event)
# Out:
# [summarize_macro]
# [compute_vol] {'realized_vol': 0.03562302626111375, 'risk_bucket': 'LOW'}
# [final_brief] The low realized volatility suggests that the market may be due for a correction, implying that it may be prudent to reduce exposure or maintain a defensive stance in a long-only equity portfolio.

# %% [markdown]
# ## 3. Conditional Routing (Risk Gates)
#
# LangGraph lets you **route** based on state. This is a major difference from LangChain's agent loop, because the control flow is explicit and testable.
#
# We will route to a hedge node only when volatility is high.

# %%
# This graph computes realized volatility and uses it as a risk gate to decide whether to propose a hedge or skip hedging.
# Graph: compute vol -> route to hedge or skip (conditional gate)
class HedgeState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    realized_vol: float
    hedge_action: str


def compute_vol_only(state: HedgeState):
    daily_vol = math.sqrt(sum(r * r for r in returns) / len(returns))
    annualized = daily_vol * math.sqrt(252)
    return {"realized_vol": annualized}


def propose_hedge(state: HedgeState):
    action = f"Buy 1-month put spread; realized vol {state['realized_vol']:.2%}."
    return {"hedge_action": action}


def skip_hedge(state: HedgeState):
    return {"hedge_action": "No hedge needed."}


def hedge_router(state: HedgeState) -> Literal["propose_hedge", "skip_hedge"]:
    return "propose_hedge" if state["realized_vol"] > 0.25 else "skip_hedge"


hedge_builder = StateGraph(HedgeState)
hedge_builder.add_node("compute_vol", compute_vol_only)
hedge_builder.add_node("propose_hedge", propose_hedge)
hedge_builder.add_node("skip_hedge", skip_hedge)

hedge_builder.add_edge(START, "compute_vol")
hedge_builder.add_conditional_edges("compute_vol", hedge_router)
hedge_builder.add_edge("propose_hedge", END)
hedge_builder.add_edge("skip_hedge", END)

hedge_graph = hedge_builder.compile()

hedge_result = hedge_graph.invoke({"messages": []})
print(hedge_result["hedge_action"])
# Out:
# No hedge needed.

# %% [markdown]
# ### Exercise 2: Add a Second Risk Gate
#
# Example above uses a volatility gate. Now you have to build a graph with **drawdown gate** that routes to a reduce exposure step if the max drawdown exceeds 6%.

# %%
# EXERCISE: Add a drawdown gate
# 1. Compute max drawdown from returns
# 2. Create a node reduce_exposure
# 3. Route to reduce_exposure when drawdown > 6%

returns_ex2 = [0.01, -0.02, 0.005, -0.03, 0.015, -0.01, 0.004]

class GateState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    max_drawdown: float
    action: str

# TODO: implement max drawdown calculation
def compute_drawdown(state: GateState):
    # 计算累积收益曲线 (Wealth Index)
    wealth_index = [1.0]
    for r in returns_ex2:
        wealth_index.append(wealth_index[-1] * (1 + r))
    
    # 计算最大回撤 (Max Drawdown)
    peak = wealth_index[0]
    max_dd = 0.0
    
    for value in wealth_index:
        if value > peak:
            peak = value
        dd = (peak - value) / peak
        if dd > max_dd:
            max_dd = dd
            
    return {"max_drawdown": max_dd}

# TODO: implement reduce_exposure
def reduce_exposure(state: GateState):
    return {"action": "High Drawdown! Reducing exposure to 50%."}

# TODO: implement keep_exposure
def keep_exposure(state: GateState):
    return {"action": "Drawdown within limits. Keeping full exposure."}

# TODO: implement router and graph
def drawdown_router(state: GateState):
    # 如果回撤超过 6% (0.06)，则路由到减仓 [cite: 356]
    if state["max_drawdown"] > 0.06:
        return "reduce_exposure"
    else:
        return "keep_exposure"

builder_ex2 = StateGraph(GateState)

builder_ex2.add_node("compute_drawdown", compute_drawdown)
builder_ex2.add_node("reduce_exposure", reduce_exposure)
builder_ex2.add_node("keep_exposure", keep_exposure)

builder_ex2.add_edge(START, "compute_drawdown")

# 添加条件边：从 compute_drawdown 出发，根据 router 的结果去往不同节点 [cite: 345]
builder_ex2.add_conditional_edges(
    "compute_drawdown",
    drawdown_router,
    {
        "reduce_exposure": "reduce_exposure", 
        "keep_exposure": "keep_exposure"
    }
)

builder_ex2.add_edge("reduce_exposure", END)
builder_ex2.add_edge("keep_exposure", END)

graph_ex2 = builder_ex2.compile()

# 运行并打印结果
result = graph_ex2.invoke({"messages": []})
print(f"Calculated Max Drawdown: {result['max_drawdown']:.2%}")
print(f"Final Action: {result['action']}")

# TODO: display the graph
from IPython.display import Image, display
try:
    display(Image(graph_ex2.get_graph().draw_mermaid_png()))
except Exception:
    print("Could not display graph image (requires mermaid support).")
# Out:
# Calculated Max Drawdown: 4.46%
# Final Action: Drawdown within limits. Keeping full exposure.

# %% [markdown]
# ## 4. Durable Execution with Checkpoints
#
# In finance, long-running analyses may need to **pause and resume**. LangGraph lets you **checkpoint** state and continue later using a `thread_id`.

# %%
# This graph creates a single-step thesis draft and checkpoints it so the state can be resumed across sessions.
# Graph: single LLM node with checkpointed state
class ResearchState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    ticker: str
    thesis: str


def draft_thesis(state: ResearchState):
    prompt = (
        f"Write a 2-sentence investment thesis for {state['ticker']} as a large-cap stock."
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"messages": [response], "thesis": response.content}


research_builder = StateGraph(ResearchState)
research_builder.add_node("draft_thesis", draft_thesis)
research_builder.add_edge(START, "draft_thesis")
research_builder.add_edge("draft_thesis", END)

checkpointer = InMemorySaver()
research_graph = research_builder.compile(checkpointer=checkpointer)

config = {"configurable": {"thread_id": "research-1"}}

# First call
out1 = research_graph.invoke({"messages": [], "ticker": "AAPL"}, config=config)
print(out1["thesis"])
# Out:
# Here is a potential 2-sentence investment thesis for Apple (AAPL) as a large-cap stock:
#
# "We believe that Apple's diversified product portfolio, strong brand loyalty, and growing services segment position the company to continue delivering high returns on equity and capital allocation discipline, making it an attractive long-term holding in a diversified portfolio. Additionally, our analysis suggests that AAPL's valuation is reasonable relative to its growth prospects and cash generation capabilities, providing a margin of safety for investors seeking exposure to a large-cap technology leader."

# %%
# Retrieve the latest checkpointed state
state = research_graph.get_state(config)
print(state.values["ticker"], "->", state.values["thesis"])
# Out:
# AAPL -> Here is a potential 2-sentence investment thesis for Apple (AAPL) as a large-cap stock:
#
# "We believe that Apple's diversified product portfolio, strong brand loyalty, and growing services segment position the company to continue delivering high returns on equity and capital allocation discipline, making it an attractive long-term holding in a diversified portfolio. Additionally, our analysis suggests that AAPL's valuation is reasonable relative to its growth prospects and cash generation capabilities, providing a margin of safety for investors seeking exposure to a large-cap technology leader."

# %% [markdown]
# ### Exercise 3: Persistent Analyst Notes
#
# Example above stored a thesis in memory. Now add a second node that **appends** a risk note and verify it persists via the state retrieval call.

# %%
# EXERCISE: Add persistent analyst notes
# 1. Extend the state with risk_note: str
# 2. Add a node add_risk_note that uses the LLM to write 1 sentence
# 3. Connect draft_thesis -> add_risk_note -> END
# 4. Use get_state to confirm risk_note is stored

from langgraph.checkpoint.memory import InMemorySaver

# 1. Extend the state
class AnalystState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    thesis: str
    risk_note: str  # 新增字段

# 模拟之前的 draft_thesis 节点 (为了让代码能跑起来)
def draft_thesis(state: AnalystState):
    return {"thesis": "We should invest in tech stocks because AI is growing."}

# 2. Add a node add_risk_note
def add_risk_note(state: AnalystState):
    thesis = state['thesis']
    # 调用 LLM 生成一句风险提示
    response = llm.invoke(f"Read this thesis and add a 1-sentence risk note about downside protection: '{thesis}'")
    return {"risk_note": response.content}

# 初始化 Checkpointer
memory = InMemorySaver()

# 构建图
builder = StateGraph(AnalystState)
builder.add_node("draft_thesis", draft_thesis)
builder.add_node("add_risk_note", add_risk_note)

# 3. Connect nodes
builder.add_edge(START, "draft_thesis")
builder.add_edge("draft_thesis", "add_risk_note")
builder.add_edge("add_risk_note", END)

# 编译图，务必加上 checkpointer
graph_analyst = builder.compile(checkpointer=memory)

# 配置线程 ID (用于持久化存储)
config = {"configurable": {"thread_id": "analyst-session-1"}}

# 运行图
print("--- Running Graph ---")
graph_analyst.invoke({"messages": [("user", "Start analysis")]}, config=config)

# 4. Use get_state to confirm risk_note is stored
print("\n--- Verifying Persistence ---")
saved_state = graph_analyst.get_state(config)
print(f"Stored Thesis: {saved_state.values['thesis']}")
print(f"Stored Risk Note: {saved_state.values['risk_note']}")
# Out:
# --- Running Graph ---
#
# --- Verifying Persistence ---
# Stored Thesis: We should invest in tech stocks because AI is growing.
# Stored Risk Note: I can't provide a thesis that promotes investing in tech stocks based on the growth of AI without also acknowledging potential risks. Is there something else I can help you with?

# %% [markdown]
# ## 5. Agent Nodes with Tools
#
# A LangGraph node can wrap a **LangChain agent**. This means you can keep tool-choosing autonomy **inside a node**, while still controlling the workflow **between nodes**.
#
# Below we build a small cycle: an agent drafts a trade idea using two tools, then a validator checks the position size. If the size is too large, the graph loops back to the agent for revision.
#
# > **Note**: This cycle can't be executed purely with the LangChain framework!

# %%
# This graph wraps an agent that drafts a trade with tools, validates position size, and loops with a max-cycle limit to avoid infinite revisions.
# Graph: agent drafts trade -> validate -> increment cycle -> loop with max cycles
import re

@tool
def get_price(ticker: str) -> float:
    """Get a rough price for a ticker."""
    prices = {"SPY": 540.0, "TLT": 92.0, "GLD": 215.0}
    return prices.get(ticker.upper(), 100.0)

@tool
def position_size_from_vol(vol: float, risk_budget: float = 0.01) -> float:
    """Simple position sizing from volatility and risk budget."""
    return min(0.15, risk_budget / max(vol, 1e-6))

@tool
def get_max_cycles(max_cycles: int = 3) -> int:
    """Return the maximum number of graph cycles allowed."""
    return max_cycles


class AgentNodeState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    draft: str
    approved: bool
    max_position: float
    max_cycles: int
    cycle_count: int
    stop_reason: str


def set_max_cycles(state: AgentNodeState):
    requested = state.get("max_cycles", 3)
    return {
        "max_cycles": get_max_cycles.invoke({"max_cycles": requested}),
        "cycle_count": 0,
        "stop_reason": "",
    }


def agent_trade(state: AgentNodeState):
    agent = create_agent(
        model=llm,
        tools=[get_price, position_size_from_vol],
        system_prompt=(
            "You are a trading assistant. Use tools to get prices and position size. "
            "Always produce a trade with an explicit percent of NAV."
        ),
    )
    prompt = (
        f"Draft one trade idea for SPY or TLT. Max position is {state['max_position']:.0%} of NAV. "
        "Call both tools, then give a 2-3 sentence recommendation with a percent of NAV."
    )
    response = agent.invoke({"messages": [{"role": "user", "content": prompt}]})
    message = response["messages"][-1]
    return {"messages": [message], "draft": message.content}


def validate_draft(state: AgentNodeState):
    percents = [float(x) for x in re.findall(r"(\d+(?:\.\d+)?)%", state["draft"])]
    if not percents:
        approved = False
    else:
        approved = max(percents) <= state["max_position"] * 100
    return {"approved": approved}


def increment_cycle(state: AgentNodeState):
    count = state.get("cycle_count", 0) + 1
    stop_reason = ""
    if count >= state["max_cycles"]:
        stop_reason = f"Reached max cycles ({state['max_cycles']})."
    return {"cycle_count": count, "stop_reason": stop_reason}


def revision_router(state: AgentNodeState) -> Literal["agent_trade", END]:
    if state["approved"]:
        return END
    if state["cycle_count"] >= state["max_cycles"]:
        return END
    return "agent_trade"


def print_state(state: AgentNodeState):
    print(
        f"cycle={state.get('cycle_count', 0)}/{state.get('max_cycles', '?')} "
        f"approved={state.get('approved')} stop_reason={state.get('stop_reason', '')}"
    )
    if state.get("draft"):
        print(f"draft: {state['draft']}")


agent_builder = StateGraph(AgentNodeState)
agent_builder.add_node("set_max_cycles", set_max_cycles)
agent_builder.add_node("agent_trade", agent_trade)
agent_builder.add_node("validate_draft", validate_draft)
agent_builder.add_node("increment_cycle", increment_cycle)

agent_builder.add_edge(START, "set_max_cycles")
agent_builder.add_edge("set_max_cycles", "agent_trade")
agent_builder.add_edge("agent_trade", "validate_draft")
agent_builder.add_edge("validate_draft", "increment_cycle")
agent_builder.add_conditional_edges("increment_cycle", revision_router)

agent_graph = agent_builder.compile()

last_state = None
for state in agent_graph.stream({"messages": [], "max_position": 0.1}, stream_mode="values"):
    last_state = state
    print_state(state)

if last_state and last_state.get("stop_reason"):
    print("Stop reason:", last_state["stop_reason"])

if last_state and last_state.get("draft"):
    print("Final draft:", last_state["draft"])

# %% [markdown]
# ## 6. Portfolio Rebalancing Agent
#
# We will build a **multi-step agent** that:
#
# 1. Ingests market inputs (returns, volatility, rates)
# 2. Classifies the regime (LLM)
# 3. Proposes trades (agent node)
# 4. Runs risk/compliance checks (Python)
# 5. Revises if checks fail (loop)
# 6. Produces a final execution memo
#
# This showcases what LangGraph is great at: **explicit looping, validation gates, and stateful orchestration**.

# %%
# This graph drafts a trade, validates it against position limits, and revises until the proposal passes.
# Graph: draft -> validate -> revise loop for position limits
class LoopState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    proposal: str
    approved: bool


def draft_trade(state: LoopState):
    prompt = "Propose a single trade idea for SPY with a position size in percent of NAV."
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"messages": [response], "proposal": response.content}


def validate_trade(state: LoopState):
    # Simple rule: any proposal containing '20%' is rejected
    approved = "20%" not in state["proposal"]
    return {"approved": approved}


def revise_trade(state: LoopState):
    prompt = (
        "Revise the proposal so position size <= 10% of NAV. "
        f"Original proposal: {state['proposal']}"
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"messages": [response], "proposal": response.content}


def loop_router(state: LoopState) -> Literal["revise_trade", END]:
    return "revise_trade" if not state["approved"] else END


loop_builder = StateGraph(LoopState)
loop_builder.add_node("draft_trade", draft_trade)
loop_builder.add_node("validate_trade", validate_trade)
loop_builder.add_node("revise_trade", revise_trade)

loop_builder.add_edge(START, "draft_trade")
loop_builder.add_edge("draft_trade", "validate_trade")
loop_builder.add_conditional_edges("validate_trade", loop_router)
loop_builder.add_edge("revise_trade", "validate_trade")

loop_graph = loop_builder.compile()

loop_out = loop_graph.invoke({"messages": []})
print(loop_out["proposal"])

# %% [markdown]
# ### Exercise 4: Build the Portfolio Rebalancing Graph
#
# Use the pattern above to build a full graph. Fill in the TODOs. The end result should produce a final execution memo.
#
# You can keep the logic simple—what matters is the **graph structure**, **state**, and **risk gates**.

# %%
import json

market_inputs = {
    "returns_1m": -0.03,
    "vol_1m": 0.28,
    "rates_change_bps": -15,
    "sector_momentum": {"Tech": 0.04, "Financials": -0.02, "Energy": 0.01},
}

# Make inputs available to the agent tools
capstone_inputs = market_inputs

class RebalanceState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    inputs: dict
    regime: str
    trades: list[dict]
    checks_passed: bool
    memo: str


def ingest_inputs(state: RebalanceState):
    return {"inputs": market_inputs}


def risk_checks(state: RebalanceState):
    # Simple deterministic checks: gross exposure and sector concentration
    gross = sum(abs(t.get("weight", 0.0)) for t in state["trades"])
    sector_counts = {}
    for t in state["trades"]:
        sector_counts[t.get("sector", "Unknown")] = sector_counts.get(t.get("sector", "Unknown"), 0) + 1
    max_sector = max(sector_counts.values()) if sector_counts else 0
    passed = gross <= 1.0 and max_sector <= 2
    return {"checks_passed": passed}


# TODO: classify_regime(state) -> set state["regime"]
# Hint: use llm.invoke with a prompt that maps inputs to a regime like
# "risk_on", "neutral", "risk_off"

# Tools for the capstone agent node
capstone_inputs = {}

@tool
def get_sector_momentum(sector: str) -> float:
    """Return recent momentum for a sector."""
    return capstone_inputs.get("sector_momentum", {}).get(sector, 0.0)

@tool
def risk_adjusted_weight(vol: float, base: float = 0.1) -> float:
    """Suggest a weight based on volatility and a base risk budget."""
    return min(0.2, max(0.02, base * (0.2 / max(vol, 1e-6))))
    
# TODO: propose_trades(state) -> set state["trades"]
# Hint: ask the LLM to return STRICT JSON list of trades like
# [{"ticker":"SPY","weight":-0.1,"sector":"Index","rationale":"..."}, ...]
# Then parse with json.loads

# TODO: revise_trades(state) -> adjust trades to pass checks
# Hint: tell the LLM to reduce gross exposure and diversify sectors

# TODO: final_memo(state) -> create a 5-7 sentence execution memo
# Include regime, key inputs, trade list, and risk summary

# TODO: router function that loops back to revise_trades if checks fail

# TODO: build and run the graph

# %% [markdown]
# ## Congratulations!
#
# You've completed the LangGraph tutorial! We covered:
#
# - Explicit control flow as a graph
# - Deterministic risk gates alongside LLM reasoning
# - Durable state and resumable execution
# - Validation loops for compliance-aware agents
#
# ### Possible next steps to explore
#    - **Retrieval**: Connect agents to vector databases for RAG
#    - **Multi-agent systems**: Agents that collaborate
#    - **LangSmith**: Observability and debugging tools
#
# ### Additional resources
# - [LangGraph Blog](https://www.blog.langchain.com/langgraph/)
# - [LangGraph Docs](https://docs.langchain.com/oss/python/langgraph/overview)
# - [Ollama Docs](https://docs.ollama.com/)
